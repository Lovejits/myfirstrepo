# %% [markdown]
# <a href="https://colab.research.google.com/github/Lovejits/myfirstrepo/blob/main/pandas_start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
df = pandas.read_csv("salaries_by_college_major.csv")

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.dropna()
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.dropna()
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df_nna = df.dropna()

# %%
df_nna.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
df_nna["Starting Median Salary"]
# Out:
# 0     46000.0
# 1     57700.0
# 2     42600.0
# 3     36800.0
# 4     41600.0
# 5     35800.0
# 6     38800.0
# 7     43000.0
# 8     63200.0
# 9     42600.0
# 10    53900.0
# 11    38100.0
# 12    61400.0
# 13    55900.0
# 14    53700.0
# 15    35000.0
# 16    35900.0
# 17    50100.0
# 18    34900.0
# 19    60900.0
# 20    38000.0
# 21    37900.0
# 22    47900.0
# 23    39100.0
# 24    41200.0
# 25    43500.0
# 26    35700.0
# 27    38800.0
# 28    39200.0
# 29    37800.0
# 30    57700.0
# 31    49100.0
# 32    36100.0
# 33    40900.0
# 34    35600.0
# 35    49200.0
# 36    40800.0
# 37    45400.0
# 38    57900.0
# 39    35900.0
# 40    54200.0
# 41    39900.0
# 42    39900.0
# 43    74300.0
# 44    50300.0
# 45    40800.0
# 46    35900.0
# 47    34100.0
# 48    36500.0
# 49    34000.0
# Name: Starting Median Salary, dtype: float64

# %%
df_nna["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
df_nna["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
df_nna["Undergraduate Major"].loc[43]
# Out:
# 'Physician Assistant'

# %%
df_nna.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
df_nna.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df_nna["Mid-Career Median Salary"].max()
# Out:
# 107000.0

# %%
df_nna["Mid-Career Median Salary"].idxmax()
# Out:
# 8

# %%
df_nna.loc[8]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %%
df_nna["Starting Median Salary"].min()
# Out:
# 34000.0

# %%
df_nna["Starting Median Salary"].idxmin()
# Out:
# 49

# %%
df_nna["Undergraduate Major"].loc[49]
# Out:
# 'Spanish'

# %%
df_nna["Mid-Career Median Salary"].idxmin()
# Out:
# 18

# %%
df_nna["Mid-Career Median Salary"].min()
# Out:
# 52000.0

# %%
df_nna["Undergraduate Major"].loc[18]
# Out:
# 'Education'

# %%
df_nna["Mid-Career 90th Percentile Salary"] - df_nna["Mid-Career 10th Percentile Salary"]
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
df_nna["Mid-Career 90th Percentile Salary"]
# Out:
# 0     152000.0
# 1     161000.0
# 2     150000.0
# 3     138000.0
# 4     136000.0
# 5     125000.0
# 6     135000.0
# 7     147000.0
# 8     194000.0
# 9     148000.0
# 10    148000.0
# 11    143000.0
# 12    162000.0
# 13    154000.0
# 14    171000.0
# 15    107000.0
# 16    153000.0
# 17    210000.0
# 18    102000.0
# 19    168000.0
# 20    133000.0
# 21    136000.0
# 22    195000.0
# 23    111000.0
# 24    132000.0
# 25    156000.0
# 26    112000.0
# 27    101000.0
# 28    149000.0
# 29    124000.0
# 30    173000.0
# 31    129000.0
# 32    107000.0
# 33    157000.0
# 34    145000.0
# 35    146000.0
# 36    175000.0
# 37    183000.0
# 38    163000.0
# 39    134000.0
# 40     98300.0
# 41     99200.0
# 42    168000.0
# 43    124000.0
# 44    178000.0
# 45    168000.0
# 46    127000.0
# 47     96400.0
# 48    118000.0
# 49     96400.0
# Name: Mid-Career 90th Percentile Salary, dtype: float64

# %%
df_nna["Mid-Career 90th Percentile Salary"].subtract(df_nna["Mid-Career 10th Percentile Salary"])
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
spread_col = df_nna["Mid-Career 90th Percentile Salary"] - df_nna["Mid-Career 10th Percentile Salary"]

# %%
df_nna.insert(1, 'Spread', spread_col)

# %%
df_nna.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
df_nna['Spread'].idxmin()
# Out:
# 40

# %%
df_nna.loc[40]
# Out:
# Undergraduate Major                   Nursing
# Spread                                50700.0
# Starting Median Salary                54200.0
# Mid-Career Median Salary              67000.0
# Mid-Career 10th Percentile Salary     47600.0
# Mid-Career 90th Percentile Salary     98300.0
# Group                                Business
# Name: 40, dtype: object

# %%
df_nna.sort_values('Mid-Career 90th Percentile Salary')
# Out:
#                      Undergraduate Major    Spread  Starting Median Salary  \
# 49                               Spanish   65400.0                 34000.0
# 47                              Religion   66700.0                 34100.0
# 40                               Nursing   50700.0                 54200.0
# 41                             Nutrition   65300.0                 39900.0
# 27            Health Care Administration   66400.0                 38800.0
# 18                             Education   72700.0                 34900.0
# 32                       Interior Design   71300.0                 36100.0
# 15                      Criminal Justice   74800.0                 35000.0
# 23                              Forestry   70000.0                 39100.0
# 26                        Graphic Design   76000.0                 35700.0
# 48                             Sociology   87300.0                 36500.0
# ...

# %%
sorted = df_nna.sort_values('Mid-Career 90th Percentile Salary')

# %%
sorted[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].tail()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 44               Physics                           178000.0
# 37                  Math                           183000.0
# 8   Chemical Engineering                           194000.0
# 22               Finance                           195000.0
# 17             Economics                           210000.0

# %%
df_nna.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
# Out:
#                      Undergraduate Major    Spread  Starting Median Salary  \
# 17                             Economics  159400.0                 50100.0
# 22                               Finance  147800.0                 47900.0
# 8                   Chemical Engineering  122100.0                 63200.0
# 37                                  Math  137800.0                 45400.0
# 44                               Physics  122000.0                 50300.0
# 36                             Marketing  132900.0                 40800.0
# 30                Industrial Engineering  115900.0                 57700.0
# 14                          Construction  114700.0                 53700.0
# 45                     Political Science  126800.0                 40800.0
# 42                            Philosophy  132500.0                 39900.0
# 19                Electrical Engineering   98700.0                 60900.0
# ...

# %%
sorted = df_nna.sort_values('Mid-Career 90th Percentile Salary', ascending=False)

# %%
sorted[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
spread_diff = df_nna.sort_values('Spread', ascending=False)

# %%
sorted[['Undergraduate Major', 'Spread']].head()
# Out:
#      Undergraduate Major    Spread
# 17             Economics  159400.0
# 22               Finance  147800.0
# 8   Chemical Engineering  122100.0
# 37                  Math  137800.0
# 44               Physics  122000.0
